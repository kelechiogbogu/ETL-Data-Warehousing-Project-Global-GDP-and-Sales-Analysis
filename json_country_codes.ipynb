# %% [markdown]
# ### Extracting the Country Codes & Regions Dataset
# This notebook fetches country information from the REST Countries API, simplifies the data to essential fields (country name, ISO codes, region) and saves it for further analysis or use in data projects.

# %%
# Requests: fetch data from APIs; JSON: parse and save data in JSON format
import requests
import json

# Correct API URL with fields
url = "https://restcountries.com/v3.1/all?fields=name,cca2,cca3,region"
response = requests.get(url)

# Check response status
if response.status_code != 200:
    print("Error fetching data:", response.status_code, response.text)
    raise SystemExit

countries_data = response.json()

# Extract relevant info
simplified_data = []
for c in countries_data:
    country_info = {
        "country": c.get("name", {}).get("common") if c.get("name") else None,
        "cca2": c.get("cca2"),
        "cca3": c.get("cca3"),
        "region": c.get("region"),
        "postal_code_format": None  # Placeholder, since API doesn't include postal codes
    }
    simplified_data.append(country_info)

# Save as JSON
with open("countries_info.json", "w", encoding="utf-8") as f:
    json.dump(simplified_data, f, indent=4)

print("countries_info.json created successfully!")
# Out:
# countries_info.json created successfully!

# %%
# Loading the JSON
with open("countries_info.json", "r", encoding="utf-8") as f:
    countries = json.load(f)

# See how many countries
print(f"Total countries: {len(countries)}")

# See the first 5 entries
for c in countries[:5]:
    print(c)
# Out:
# Total countries: 250
# {'country': 'Andorra', 'cca2': 'AD', 'cca3': 'AND', 'region': 'Europe', 'postal_code_format': None}
# {'country': 'Trinidad and Tobago', 'cca2': 'TT', 'cca3': 'TTO', 'region': 'Americas', 'postal_code_format': None}
# {'country': 'Serbia', 'cca2': 'RS', 'cca3': 'SRB', 'region': 'Europe', 'postal_code_format': None}
# {'country': 'United Kingdom', 'cca2': 'GB', 'cca3': 'GBR', 'region': 'Europe', 'postal_code_format': None}
# {'country': 'Russia', 'cca2': 'RU', 'cca3': 'RUS', 'region': 'Europe', 'postal_code_format': None}

# %%
import pandas as pd

df_countries = pd.DataFrame(countries)

# Preview the first rows
print(df_countries.head())

# See columns
print(df_countries.columns)

# Summary of regions
print(df_countries['region'].value_counts())
# Out:
#                country cca2 cca3    region postal_code_format
# 0              Andorra   AD  AND    Europe               None
# 1  Trinidad and Tobago   TT  TTO  Americas               None
# 2               Serbia   RS  SRB    Europe               None
# 3       United Kingdom   GB  GBR    Europe               None
# 4               Russia   RU  RUS    Europe               None
# Index(['country', 'cca2', 'cca3', 'region', 'postal_code_format'], dtype='object')
# Africa       59
# Americas     56
# Europe       53
# Asia         50
# Oceania      27
# Antarctic     5
# Name: region, dtype: int64

# %%
# Select only the relevant columns
Countries_df = df_countries[["cca2", "country", "region"]]

# %%
# To glance through the whole table
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

display(Countries_df)
# Out:
#     cca2                                       country     region
# 0     AD                                       Andorra     Europe
# 1     TT                           Trinidad and Tobago   Americas
# 2     RS                                        Serbia     Europe
# 3     GB                                United Kingdom     Europe
# 4     RU                                        Russia     Europe
# 5     HK                                     Hong Kong       Asia
# 6     EH                                Western Sahara     Africa
# 7     UY                                       Uruguay   Americas
# 8     BB                                      Barbados   Americas
# 9     PS                                     Palestine       Asia
# 10    MX                                        Mexico   Americas
# 11    MW                                        Malawi     Africa
# 12    AQ                                    Antarctica  Antarctic
# 13    NC                                 New Caledonia    Oceania
# 14    SJ                        Svalbard and Jan Mayen     Europe
# 15    NF                                Norfolk Island    Oceania
# 16    CX                              Christmas Island    Oceania
# 17    MN                                      Mongolia       Asia
# 18    LV                                        Latvia     Europe
# 19    BN                                        Brunei       Asia
# 20    UA                                       Ukraine     Europe
# 21    KP                                   North Korea       Asia
# 22    FI                                       Finland     Europe
# 23    AI                                      Anguilla   Americas
# 24    AZ                                    Azerbaijan       Asia
# 25    KY                                Cayman Islands   Americas
# 26    UZ                                    Uzbekistan       Asia
# 27    IE                                       Ireland     Europe
# 28    JE                                        Jersey     Europe
# 29    RW                                        Rwanda     Africa
# 30    BA                        Bosnia and Herzegovina     Europe
# 31    PL                                        Poland     Europe
# 32    PT                                      Portugal     Europe
# 33    HT                                         Haiti   Americas
# 34    IR                                          Iran       Asia
# 35    TF           French Southern and Antarctic Lands  Antarctic
# 36    ET                                      Ethiopia     Africa
# 37    KZ                                    Kazakhstan       Asia
# 38    ML                                          Mali     Africa
# 39    NI                                     Nicaragua   Americas
# 40    DE                                       Germany     Europe
# 41    EE                                       Estonia     Europe
# 42    TN                                       Tunisia     Africa
# 43    MF                                  Saint Martin   Americas
# 44    CM                                      Cameroon     Africa
# 45    FM                                    Micronesia    Oceania
# 46    SX                                  Sint Maarten   Americas
# 47    CY                                        Cyprus     Europe
# 48    MA                                       Morocco     Africa
# 49    PN                              Pitcairn Islands    Oceania
# 50    CW                                       Curaçao   Americas
# 51    AW                                         Aruba   Americas
# 52    ES                                         Spain     Europe
# 53    GA                                         Gabon     Africa
# 54    AX                                 Åland Islands     Europe
# 55    DK                                       Denmark     Europe
# 56    MQ                                    Martinique   Americas
# 57    AG                           Antigua and Barbuda   Americas
# 58    SZ                                      Eswatini     Africa
# 59    TW                                        Taiwan       Asia
# 60    VU                                       Vanuatu    Oceania
# 61    CK                                  Cook Islands    Oceania
# 62    CC                       Cocos (Keeling) Islands    Oceania
# 63    CV                                    Cape Verde     Africa
# 64    BY                                       Belarus     Europe
# 65    CZ                                       Czechia     Europe
# 66    PE                                          Peru   Americas
# 67    TL                                   Timor-Leste       Asia
# 68    NA                                       Namibia     Africa
# 69    TK                                       Tokelau    Oceania
# 70    CD                                      DR Congo     Africa
# 71    LC                                   Saint Lucia   Americas
# 72    SR                                      Suriname   Americas
# 73    BI                                       Burundi     Africa
# 74    GE                                       Georgia       Asia
# 75    GH                                         Ghana     Africa
# 76    IO                British Indian Ocean Territory     Africa
# 77    EG                                         Egypt     Africa
# 78    GF                                 French Guiana   Americas
# 79    MH                              Marshall Islands    Oceania
# 80    GW                                 Guinea-Bissau     Africa
# 81    FJ                                          Fiji    Oceania
# 82    ZM                                        Zambia     Africa
# 83    IS                                       Iceland     Europe
# 84    BM                                       Bermuda   Americas
# 85    BR                                        Brazil   Americas
# 86    PW                                         Palau    Oceania
# 87    SD                                         Sudan     Africa
# 88    AU                                     Australia    Oceania
# 89    KH                                      Cambodia       Asia
# 90    NZ                                   New Zealand    Oceania
# 91    PH                                   Philippines       Asia
# 92    BF                                  Burkina Faso     Africa
# 93    FO                                 Faroe Islands     Europe
# 94    SL                                  Sierra Leone     Africa
# 95    GD                                       Grenada   Americas
# 96    BO                                       Bolivia   Americas
# 97    CH                                   Switzerland     Europe
# 98    VC              Saint Vincent and the Grenadines   Americas
# 99    EC                                       Ecuador   Americas
# 100   SC                                    Seychelles     Africa
# 101   ZA                                  South Africa     Africa
# 102   IN                                         India       Asia
# 103   LR                                       Liberia     Africa
# 104   KR                                   South Korea       Asia
# 105   LT                                     Lithuania     Europe
# 106   SG                                     Singapore       Asia
# 107   PR                                   Puerto Rico   Americas
# 108   BZ                                        Belize   Americas
# 109   NL                                   Netherlands     Europe
# 110   ER                                       Eritrea     Africa
# 111   MS                                    Montserrat   Americas
# 112   RE                                       Réunion     Africa
# 113   GS                                 South Georgia  Antarctic
# 114   BD                                    Bangladesh       Asia
# 115   YE                                         Yemen       Asia
# 116   NO                                        Norway     Europe
# 117   SI                                      Slovenia     Europe
# 118   OM                                          Oman       Asia
# 119   MZ                                    Mozambique     Africa
# 120   LY                                         Libya     Africa
# 121   TD                                          Chad     Africa
# 122   GY                                        Guyana   Americas
# 123   KG                                    Kyrgyzstan       Asia
# 124   DJ                                      Djibouti     Africa
# 125   MP                      Northern Mariana Islands    Oceania
# 126   US                                 United States   Americas
# 127   TG                                          Togo     Africa
# 128   LK                                     Sri Lanka       Asia
# 129   KM                                       Comoros     Africa
# 130   CU                                          Cuba   Americas
# 131   GU                                          Guam    Oceania
# 132   AR                                     Argentina   Americas
# 133   WF                             Wallis and Futuna    Oceania
# 134   BT                                        Bhutan       Asia
# 135   LB                                       Lebanon       Asia
# 136   HM             Heard Island and McDonald Islands  Antarctic
# 137   LS                                       Lesotho     Africa
# 138   SO                                       Somalia     Africa
# 139   DM                                      Dominica   Americas
# 140   HU                                       Hungary     Europe
# 141   LU                                    Luxembourg     Europe
# 142   SM                                    San Marino     Europe
# 143   AF                                   Afghanistan       Asia
# 144   MR                                    Mauritania     Africa
# 145   DZ                                       Algeria     Africa
# 146   GP                                    Guadeloupe   Americas
# 147   HR                                       Croatia     Europe
# 148   BG                                      Bulgaria     Europe
# 149   NU                                          Niue    Oceania
# 150   ID                                     Indonesia       Asia
# 151   BE                                       Belgium     Europe
# 152   NR                                         Nauru    Oceania
# 153   PF                              French Polynesia    Oceania
# 154   IQ                                          Iraq       Asia
# 155   MG                                    Madagascar     Africa
# 156   VN                                       Vietnam       Asia
# 157   MU                                     Mauritius     Africa
# 158   AS                                American Samoa    Oceania
# 159   CI                                   Ivory Coast     Africa
# 160   BQ                         Caribbean Netherlands   Americas
# 161   LI                                 Liechtenstein     Europe
# 162   IT                                         Italy     Europe
# 163   KN                         Saint Kitts and Nevis   Americas
# 164   QA                                         Qatar       Asia
# 165   TR                                        Turkey       Asia
# 166   VI                  United States Virgin Islands   Americas
# 167   AO                                        Angola     Africa
# 168   KE                                         Kenya     Africa
# 169   SA                                  Saudi Arabia       Asia
# 170   SS                                   South Sudan     Africa
# 171   TC                      Turks and Caicos Islands   Americas
# 172   CA                                        Canada   Americas
# 173   NE                                         Niger     Africa
# 174   GI                                     Gibraltar     Europe
# 175   KW                                        Kuwait       Asia
# 176   VE                                     Venezuela   Americas
# 177   GM                                        Gambia     Africa
# 178   PY                                      Paraguay   Americas
# 179   CL                                         Chile   Americas
# 180   MK                               North Macedonia     Europe
# 181   MO                                         Macau       Asia
# 182   AM                                       Armenia       Asia
# 183   BW                                      Botswana     Africa
# 184   NP                                         Nepal       Asia
# 185   ST                         São Tomé and Príncipe     Africa
# 186   BJ                                         Benin     Africa
# 187   SB                               Solomon Islands    Oceania
# 188   GN                                        Guinea     Africa
# 189   YT                                       Mayotte     Africa
# 190   GL                                     Greenland   Americas
# 191   MC                                        Monaco     Europe
# 192   PK                                      Pakistan       Asia
# 193   MY                                      Malaysia       Asia
# 194   XK                                        Kosovo     Europe
# 195   MD                                       Moldova     Europe
# 196   TV                                        Tuvalu    Oceania
# 197   PM                     Saint Pierre and Miquelon   Americas
# 198   SN                                       Senegal     Africa
# 199   PA                                        Panama   Americas
# 200   MT                                         Malta     Europe
# 201   UG                                        Uganda     Africa
# 202   AL                                       Albania     Europe
# 203   AE                          United Arab Emirates       Asia
# 204   CR                                    Costa Rica   Americas
# 205   BL                              Saint Barthélemy   Americas
# 206   SH  Saint Helena, Ascension and Tristan da Cunha     Africa
# 207   IL                                        Israel       Asia
# 208   AT                                       Austria     Europe
# 209   LA                                          Laos       Asia
# 210   FR                                        France     Europe
# 211   PG                              Papua New Guinea    Oceania
# 212   DO                            Dominican Republic   Americas
# 213   TO                                         Tonga    Oceania
# 214   JM                                       Jamaica   Americas
# 215   BV                                 Bouvet Island  Antarctic
# 216   SK                                      Slovakia     Europe
# 217   KI                                      Kiribati    Oceania
# 218   JO                                        Jordan       Asia
# 219   MV                                      Maldives       Asia
# 220   ME                                    Montenegro     Europe
# 221   JP                                         Japan       Asia
# 222   SV                                   El Salvador   Americas
# 223   CO                                      Colombia   Americas
# 224   ZW                                      Zimbabwe     Africa
# 225   GQ                             Equatorial Guinea     Africa
# 226   CN                                         China       Asia
# 227   HN                                      Honduras   Americas
# 228   IM                                   Isle of Man     Europe
# 229   CG                         Republic of the Congo     Africa
# 230   MM                                       Myanmar       Asia
# 231   GR                                        Greece     Europe
# 232   WS                                         Samoa    Oceania
# 233   FK                              Falkland Islands   Americas
# 234   TZ                                      Tanzania     Africa
# 235   CF                      Central African Republic     Africa
# 236   RO                                       Romania     Europe
# 237   UM          United States Minor Outlying Islands   Americas
# 238   TJ                                    Tajikistan       Asia
# 239   BS                                       Bahamas   Americas
# 240   NG                                       Nigeria     Africa
# 241   VA                                  Vatican City     Europe
# 242   BH                                       Bahrain       Asia
# 243   TH                                      Thailand       Asia
# 244   SE                                        Sweden     Europe
# 245   VG                        British Virgin Islands   Americas
# 246   GG                                      Guernsey     Europe
# 247   GT                                     Guatemala   Americas
# 248   SY                                         Syria       Asia
# 249   TM                                  Turkmenistan       Asia

# %%
# Library to manage database connections and execute SQL queries
from sqlalchemy import create_engine

# SQL Server connection
server = "*******\\SQLEXPRESS"
database = "DWETL"

connection_string = f"mssql+pyodbc://@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
engine = create_engine(connection_string)

# Load Countries_df into SQL Server
Countries_df.to_sql(
    'CountryCodes',    
    con=engine,
    schema='dbo',
    if_exists='replace', 
    index=False
)

print("Countries_df with region loaded successfully into SQL Server!")
# Out:
# Countries_df with region loaded successfully into SQL Server!
